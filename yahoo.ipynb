# %% [markdown]
# <a href="https://colab.research.google.com/github/softwareeng1/Acquiring-financial-data/blob/main/yahoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Getting Data from Yahoo Finance
import yfinance as yf
import pandas as pd
df = yf.download("AAPL", start="2010-01-01", end="2021-12-31",progress=False)
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-01-04  7.622500  7.660714  7.585000  7.643214   6.461978  493729600
# 2010-01-05  7.664286  7.699643  7.616071  7.656429   6.473149  601904800
# 2010-01-06  7.656429  7.686786  7.526786  7.534643   6.370184  552160000
# 2010-01-07  7.562500  7.571429  7.466071  7.520714   6.358407  477131200
# 2010-01-08  7.510714  7.571429  7.466429  7.570714   6.400681  447610800
