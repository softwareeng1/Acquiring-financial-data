# %% [markdown]
# <a href="https://colab.research.google.com/github/softwareeng1/Acquiring-financial-data/blob/main/Alphavantage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install alpha_vantage

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
ALPHA_VANTAGE_API_KEY = 'place holder fo api key'
crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY, output_format='pandas')

# %%
data, meta_data = crypto_api.get_digital_currency_daily(symbol='BTC', market='EUR')

# %%
data
# Out:
#              1. open   2. high    3. low  4. close   5. volume
# date
# 2024-07-20  61312.15  61433.24  60939.53  60939.53    6.011479
# 2024-07-19  58675.01  62000.00  58111.70  61282.00  410.553202
# 2024-07-18  58599.56  59624.66  58031.47  58709.62  214.245187
# 2024-07-17  59707.23  60675.00  58347.46  58600.56  346.319649
# 2024-07-16  59421.37  59998.99  57211.79  59699.03  405.946137
# ...              ...       ...       ...       ...         ...
# 2023-09-29  25576.41  25677.27  25206.27  25446.68  301.413134
# 2023-09-28  25084.17  25800.00  25036.46  25576.55  509.130050
# 2023-09-27  24787.51  25447.69  24781.48  25081.18  405.811484
# 2023-09-26  24814.14  24918.69  24641.93  24788.36  361.405949
# 2023-09-25  24654.33  24946.98  24415.00  24812.19  391.045351
#
# [300 rows x 5 columns]

# %%
meta_data
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'BTC',
#  '3. Digital Currency Name': 'Bitcoin',
#  '4. Market Code': 'EUR',
#  '5. Market Name': 'Euro',
#  '6. Last Refreshed': '2024-07-21 00:00:00',
#  '7. Time Zone': 'UTC'}

# %%
crypto_api.get_digital_currency_exchange_rate(from_currency='BTC', to_currency='USD')[0].transpose()
# Out:
#                       Realtime Currency Exchange Rate
# 1. From_Currency Code                             BTC
# 2. From_Currency Name                         Bitcoin
# 3. To_Currency Code                               USD
# 4. To_Currency Name              United States Dollar
# 5. Exchange Rate                       66832.64000000
# 6. Last Refreshed                 2024-07-21 08:58:05
# 7. Time Zone                                      UTC
# 8. Bid Price                           66831.62700000
# 9. Ask Price                           66833.65200000
